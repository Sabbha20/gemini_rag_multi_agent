# %% [markdown]
# ## Binding Tools using Langchain genai

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain.messages import HumanMessage, SystemMessage, AIMessage, ToolMessage

# %%
from zmaza_scripts import base_tools
from zmaza_scripts.llm_models import gemini2

# %%
model = ChatGoogleGenerativeAI(model=gemini2)

model_with_tools = model.bind_tools([base_tools.z_web_search, base_tools.z_get_weater])

# %%
model_with_tools
# Out:
# RunnableBinding(bound=ChatGoogleGenerativeAI(profile={'max_input_tokens': 1048576, 'max_output_tokens': 65536, 'image_inputs': True, 'audio_inputs': True, 'pdf_inputs': True, 'video_inputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': True, 'tool_calling': True, 'structured_output': True, 'image_url_inputs': True, 'image_tool_message': True, 'tool_choice': True}, google_api_key=SecretStr('**********'), model='gemini-2.5-flash', client=<google.genai.client.Client object at 0x1113df770>, default_metadata=(), model_kwargs={}), kwargs={'tools': [{'type': 'function', 'function': {'name': 'z_web_search', 'description': 'Perform live web search using ollama\n\nArgs:\n    query (str): search query string\nReturns:\n    JSON string of top results (max 2)', 'parameters': {'properties': {'query': {'type': 'string'}}, 'required': ['query'], 'type': 'object'}}}, {'type': 'function', 'function': {'name': 'z_get_weater', 'description': 'Get curr
# ...

# %%
model_response = model_with_tools.invoke("what is the weather in Indore? and what is the history of Indore?")

# %%
model_response
# Out:
# AIMessage(content='', additional_kwargs={'function_call': {'name': 'z_web_search', 'arguments': '{"query": "history of Indore"}'}, '__gemini_function_call_thought_signatures__': {'3d03f518-fd13-458d-85db-9fafb354ad90': '...'}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019b9771-24a3-7951-95ac-203907e7fe65-0', tool_calls=[{'name': 'z_get_weater', 'args': {'location': 'Indore'}, 'id': '3d03f518-fd13-458d-85db-9fafb354ad90', 'type': 'tool_call'}, {'name': 'z_web_search', 'args': {'query': 'history of Indore'}, 'id': '8b7ac92b-969f-46cc-8926-0726018721ac', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 212, 'output_tokens': 116, 'total_tokens': 328, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 78}})
