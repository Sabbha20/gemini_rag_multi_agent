# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
import os

# os.environ

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain.messages import AIMessage, HumanMessage, SystemMessage

# %%
gemini3 = "gemini-3-pro-preview"
gemini2 = "gemini-2.5-flash"

system_msg = SystemMessage(content="You are a helpful assistant.")
user_query = HumanMessage(content="Explain the theory of relativity in simple terms.")

msgs = [system_msg, user_query]

# %%
model = ChatGoogleGenerativeAI(model=gemini3)
response = model.invoke(msgs)

# %%
response.text
# Out:
# 'The theory of relativity, proposed by Albert Einstein, is actually two theories put together: **Special Relativity** (1905) and **General Relativity** (1915).\n\nAt its core, relativity says that the universe is not a fixed, rigid framework. Instead, **space and time can bend, stretch, and change** depending on how you are moving and how much gravity is near you.\n\nHere is the breakdown in simple terms:\n\n---\n\n### Part 1: Special Relativity (The Speed of Light)\n\nThis part deals with things moving very fast—close to the speed of light. It relies on two main rules:\n\n1.  **Everything is relative:** If you are on a smooth train moving at 100 mph and you drop a ball, it falls straight down. To you, the ball is normal. To someone standing outside watching the train pass, the ball is moving forward at 100 mph while falling. How you see the world depends on your point of view (your "frame of reference").\n2.  **The speed of light is constant:** This is the weird part. No matter how fast you are moving, the speed of light is always the same.\n\n**The Consequences:**\nBecause the speed of light cannot change, other things—like time and space—must change to accommodate it.\n\n*   **Time slows down:** If you could travel in a spaceship at 99% the speed of light, time would pass normally for you. However, if you returned to Earth, you would find that you have aged only a few years, while everyone on Earth has aged decades. This is called **time dilation**.\n*   **$E = mc^2$:** This famous equation means that mass (matter) and energy are actually the same thing. A small amount of mass can be converted into a huge amount of energy (which is how nuclear power and the sun work).\n\n---\n\n### Part 2: General Relativity (Gravity)\n\nSpecial Relativity didn\'t explain gravity. Einstein spent 10 more years figuring that out.\n\nBefore Einstein, Isaac Newton said gravity was an invisible force pulling things together. Einstein said: **No, gravity is not a force; it is a curvature of space.**\n\n**The Analogy:**\nImagine a trampoline.\n1.  If you place a bowling ball (the Sun) in the middle, the fabric curves downward.\n2.  If you roll a marble (Earth) along the edge, it won\'t go in a straight line. It will roll around the bowling ball because it is following the curve of the fabric.\n\nEinstein realized that **space and time are woven together** into a fabric called "spacetime." Massive objects like stars and planets bend this fabric. We perceive this bending as gravity.\n\n---\n\n### Why does this matter in real life?\n\nYou use relativity every day if you use **GPS**.\n\nGPS satellites are moving fast (Special Relativity) and are far away from Earth\'s gravity (General Relativity). Because of this, the clocks on the satellites tick at a slightly different speed than the clocks on your phone.\n\nIf engineers didn\'t use Einstein\'s math to correct those clocks, your GPS map would be off by about **10 kilometers (6 miles) every single day!**\n\n### Summary\n*   **Special Relativity:** Time slows down and objects get heavier the faster they move.\n*   **General Relativity:** Heavy objects bend the fabric of space, creating what we feel as gravity.'

# %%
response.content
# Out:
# [{'type': 'text',
#   'text': 'The theory of relativity, proposed by Albert Einstein, is actually two theories put together: **Special Relativity** (1905) and **General Relativity** (1915).\n\nAt its core, relativity says that the universe is not a fixed, rigid framework. Instead, **space and time can bend, stretch, and change** depending on how you are moving and how much gravity is near you.\n\nHere is the breakdown in simple terms:\n\n---\n\n### Part 1: Special Relativity (The Speed of Light)\n\nThis part deals with things moving very fast—close to the speed of light. It relies on two main rules:\n\n1.  **Everything is relative:** If you are on a smooth train moving at 100 mph and you drop a ball, it falls straight down. To you, the ball is normal. To someone standing outside watching the train pass, the ball is moving forward at 100 mph while falling. How you see the world depends on your point of view (your "frame of reference").\n2.  **The speed of light is constant:** This is the weird part. No matter how fast you are moving, the speed of light is always the same.\n\n**The Consequences:**\nBecause the speed of light cannot change, other things—like time and space—must change to accommodate it.\n\n*   **Time slows down:** If you could travel in a spaceship at 99% the speed of light, time would pass normally for you. However, if you returned to Earth, you would find that you have aged only a few years, while everyone on Earth has aged decades. This is called **time dilation**.\n*   **$E = mc^2$:** This famous equation means that mass (matter) and energy are actually the same thing. A small amount of mass can be converted into a huge amount of energy (which is how nuclear power and the sun work).\n\n---\n\n### Part 2: General Relativity (Gravity)\n\nSpecial Relativity didn\'t explain gravity. Einstein spent 10 more years figuring that out.\n\nBefore Einstein, Isaac Newton said gravity was an invisible force pulling things together. Einstein said: **No, gravity is not a force; it is a curvature of space.**\n\n**The Analogy:**\nImagine a trampoline.\n1.  If you place a bowling ball (the Sun) in the middle, the fabric curves downward.\n2.  If you roll a marble (Earth) along the edge, it won\'t go in a straight line. It will roll around the bowling ball because it is following the curve of the fabric.\n\nEinstein realized that **space and time are woven together** into a fabric called "spacetime." Massive objects like stars and planets bend this fabric. We perceive this bending as gravity.\n\n---\n\n### Why does this matter in real life?\n\nYou use relativity every day if you use **GPS**.\n\nGPS satellites are moving fast (Special Relativity) and are far away from Earth\'s gravity (General Relativity). Because of this, the clocks on the satellites tick at a slightly different speed than the clocks on your phone.\n\nIf engineers didn\'t use Einstein\'s math to correct those clocks, your GPS map would be off by about **10 kilometers (6 miles) every single day!**\n\n### Summary\n*   **Special Relativity:** Time slows down and objects get heavier the faster they move.\n*   **General Relativity:** Heavy objects bend the fabric of space, creating what we feel as gravity.',
#   'extras': {'signature': '...'}}]

# %%
response.content_blocks
# Out:
# [{'type': 'text',
#   'text': 'The theory of relativity, proposed by Albert Einstein, is actually two theories put together: **Special Relativity** (1905) and **General Relativity** (1915).\n\nAt its core, relativity says that the universe is not a fixed, rigid framework. Instead, **space and time can bend, stretch, and change** depending on how you are moving and how much gravity is near you.\n\nHere is the breakdown in simple terms:\n\n---\n\n### Part 1: Special Relativity (The Speed of Light)\n\nThis part deals with things moving very fast—close to the speed of light. It relies on two main rules:\n\n1.  **Everything is relative:** If you are on a smooth train moving at 100 mph and you drop a ball, it falls straight down. To you, the ball is normal. To someone standing outside watching the train pass, the ball is moving forward at 100 mph while falling. How you see the world depends on your point of view (your "frame of reference").\n2.  **The speed of light is constant:** This is the weird part. No matter how fast you are moving, the speed of light is always the same.\n\n**The Consequences:**\nBecause the speed of light cannot change, other things—like time and space—must change to accommodate it.\n\n*   **Time slows down:** If you could travel in a spaceship at 99% the speed of light, time would pass normally for you. However, if you returned to Earth, you would find that you have aged only a few years, while everyone on Earth has aged decades. This is called **time dilation**.\n*   **$E = mc^2$:** This famous equation means that mass (matter) and energy are actually the same thing. A small amount of mass can be converted into a huge amount of energy (which is how nuclear power and the sun work).\n\n---\n\n### Part 2: General Relativity (Gravity)\n\nSpecial Relativity didn\'t explain gravity. Einstein spent 10 more years figuring that out.\n\nBefore Einstein, Isaac Newton said gravity was an invisible force pulling things together. Einstein said: **No, gravity is not a force; it is a curvature of space.**\n\n**The Analogy:**\nImagine a trampoline.\n1.  If you place a bowling ball (the Sun) in the middle, the fabric curves downward.\n2.  If you roll a marble (Earth) along the edge, it won\'t go in a straight line. It will roll around the bowling ball because it is following the curve of the fabric.\n\nEinstein realized that **space and time are woven together** into a fabric called "spacetime." Massive objects like stars and planets bend this fabric. We perceive this bending as gravity.\n\n---\n\n### Why does this matter in real life?\n\nYou use relativity every day if you use **GPS**.\n\nGPS satellites are moving fast (Special Relativity) and are far away from Earth\'s gravity (General Relativity). Because of this, the clocks on the satellites tick at a slightly different speed than the clocks on your phone.\n\nIf engineers didn\'t use Einstein\'s math to correct those clocks, your GPS map would be off by about **10 kilometers (6 miles) every single day!**\n\n### Summary\n*   **Special Relativity:** Time slows down and objects get heavier the faster they move.\n*   **General Relativity:** Heavy objects bend the fabric of space, creating what we feel as gravity.',
#   'extras': {'signature': '...'}}]

# %%
response.usage_metadata
# Out:
# {'input_tokens': 16,
#  'output_tokens': 1646,
#  'total_tokens': 1662,
#  'input_token_details': {'cache_read': 0},
#  'output_token_details': {'reasoning': 914}}

# %%
response.response_metadata
# Out:
# {'finish_reason': 'STOP',
#  'model_name': 'gemini-3-pro-preview',
#  'safety_ratings': [],
#  'model_provider': 'google_genai'}

# %%
model = ChatGoogleGenerativeAI(model=gemini2)
response = model.invoke(msgs)

# %%
response
# Out:
# AIMessage(content='Albert Einstein\'s theory of relativity is one of the most famous and profound scientific theories, revolutionizing our understanding of space, time, gravity, and the universe. It\'s actually two interconnected theories: **Special Relativity** and **General Relativity**.\n\nLet\'s break them down in simple terms:\n\n---\n\n### Part 1: Special Relativity (1905)\n\nThis theory deals with how space and time are related for objects moving at **constant speeds** (not accelerating). It has two main postulates (fundamental assumptions):\n\n1.  **The Principle of Relativity:** The laws of physics are the same for everyone, no matter how fast or in what direction they\'re moving, as long as they\'re moving at a constant speed.\n    *   **Analogy:** If you\'re on a smooth-riding train with the windows closed, you can\'t tell if you\'re moving or standing still just by doing experiments inside the train (like dropping a ball). The physics works the same.\n\n2.  **The Constancy of the Speed of Light:** The speed of light in a vacuum is the same for everyone, regardless of how fast they themselves are moving. It\'s an absolute cosmic speed limit.\n    *   **Analogy:** If you throw a ball forward from a moving car, the ball\'s speed *adds* to the car\'s speed. But if you shine a flashlight forward from a moving spaceship, the light *doesn\'t* go faster than if you shone it from a stationary flashlight. It always travels at the exact same speed (about 300,000 kilometers per second or 186,000 miles per second).\n\n**What are the mind-bending consequences of Special Relativity?**\n\nBecause the speed of light *must* be constant for all observers, other things we thought were constant (like time and distance) have to change!\n\n*   **Time Dilation:** Moving clocks run slower.\n    *   If you fly past Earth in a very fast spaceship, people on Earth would see your clock ticking slower than theirs. And from your perspective, *their* clocks would seem to tick slower! The effect is only noticeable at speeds close to light speed. This means a twin who travels to a distant star at near light speed would return to find their Earth-bound twin had aged more.\n*   **Length Contraction:** Moving objects get shorter in the direction of their motion.\n    *   A spaceship flying past you at near light speed would appear squashed or shorter to you, along the direction it\'s traveling.\n*   **Mass-Energy Equivalence (E=mc²):** Mass and energy are interchangeable.\n    *   This is arguably the most famous equation. It says that mass (M) is a very concentrated form of energy (E), and vice versa. \'c\' is the speed of light, and \'c²\' is a huge number, meaning even a tiny bit of mass can be converted into an enormous amount of energy (like in nuclear reactions or the sun).\n\n---\n\n### Part 2: General Relativity (1915)\n\nThis theory expands on Special Relativity to include **gravity** and **acceleration**. Einstein realized that his previous theory couldn\'t fully explain gravity.\n\n**The Core Idea:** Gravity is not a force that pulls objects together (like Isaac Newton thought). Instead, gravity is the **curvature of spacetime** caused by massive objects.\n\n*   **Analogy:** Imagine a stretched rubber sheet. If you place a bowling ball in the middle, it creates a dip or a "dent" in the sheet. Now, if you roll smaller marbles across the sheet, they don\'t roll in a straight line; they curve inwards towards the bowling ball because of the dip.\n*   **Applying it:**\n    *   Massive objects like Earth or the Sun are like the bowling ball. They warp the "fabric" of spacetime around them.\n    *   Objects like you, me, or planets are like the marbles. We\'re not being "pulled" by a force; we\'re simply following the curves and "dents" that massive objects have created in spacetime. The Earth orbits the Sun because it\'s following the curve in spacetime caused by the Sun\'s immense mass.\n\n**What are the mind-bending consequences of General Rela ...

# %%
response.text
# Out:
# 'Albert Einstein\'s theory of relativity is one of the most famous and profound scientific theories, revolutionizing our understanding of space, time, gravity, and the universe. It\'s actually two interconnected theories: **Special Relativity** and **General Relativity**.\n\nLet\'s break them down in simple terms:\n\n---\n\n### Part 1: Special Relativity (1905)\n\nThis theory deals with how space and time are related for objects moving at **constant speeds** (not accelerating). It has two main postulates (fundamental assumptions):\n\n1.  **The Principle of Relativity:** The laws of physics are the same for everyone, no matter how fast or in what direction they\'re moving, as long as they\'re moving at a constant speed.\n    *   **Analogy:** If you\'re on a smooth-riding train with the windows closed, you can\'t tell if you\'re moving or standing still just by doing experiments inside the train (like dropping a ball). The physics works the same.\n\n2.  **The Constancy of the Speed of Light:** The speed of light in a vacuum is the same for everyone, regardless of how fast they themselves are moving. It\'s an absolute cosmic speed limit.\n    *   **Analogy:** If you throw a ball forward from a moving car, the ball\'s speed *adds* to the car\'s speed. But if you shine a flashlight forward from a moving spaceship, the light *doesn\'t* go faster than if you shone it from a stationary flashlight. It always travels at the exact same speed (about 300,000 kilometers per second or 186,000 miles per second).\n\n**What are the mind-bending consequences of Special Relativity?**\n\nBecause the speed of light *must* be constant for all observers, other things we thought were constant (like time and distance) have to change!\n\n*   **Time Dilation:** Moving clocks run slower.\n    *   If you fly past Earth in a very fast spaceship, people on Earth would see your clock ticking slower than theirs. And from your perspective, *their* clocks would seem to tick slower! The effect is only noticeable at speeds close to light speed. This means a twin who travels to a distant star at near light speed would return to find their Earth-bound twin had aged more.\n*   **Length Contraction:** Moving objects get shorter in the direction of their motion.\n    *   A spaceship flying past you at near light speed would appear squashed or shorter to you, along the direction it\'s traveling.\n*   **Mass-Energy Equivalence (E=mc²):** Mass and energy are interchangeable.\n    *   This is arguably the most famous equation. It says that mass (M) is a very concentrated form of energy (E), and vice versa. \'c\' is the speed of light, and \'c²\' is a huge number, meaning even a tiny bit of mass can be converted into an enormous amount of energy (like in nuclear reactions or the sun).\n\n---\n\n### Part 2: General Relativity (1915)\n\nThis theory expands on Special Relativity to include **gravity** and **acceleration**. Einstein realized that his previous theory couldn\'t fully explain gravity.\n\n**The Core Idea:** Gravity is not a force that pulls objects together (like Isaac Newton thought). Instead, gravity is the **curvature of spacetime** caused by massive objects.\n\n*   **Analogy:** Imagine a stretched rubber sheet. If you place a bowling ball in the middle, it creates a dip or a "dent" in the sheet. Now, if you roll smaller marbles across the sheet, they don\'t roll in a straight line; they curve inwards towards the bowling ball because of the dip.\n*   **Applying it:**\n    *   Massive objects like Earth or the Sun are like the bowling ball. They warp the "fabric" of spacetime around them.\n    *   Objects like you, me, or planets are like the marbles. We\'re not being "pulled" by a force; we\'re simply following the curves and "dents" that massive objects have created in spacetime. The Earth orbits the Sun because it\'s following the curve in spacetime caused by the Sun\'s immense mass.\n\n**What are the mind-bending consequences of General Relativity?**\n\n*   * ...

# %%
response.content
# Out:
# 'Albert Einstein\'s theory of relativity is one of the most famous and profound scientific theories, revolutionizing our understanding of space, time, gravity, and the universe. It\'s actually two interconnected theories: **Special Relativity** and **General Relativity**.\n\nLet\'s break them down in simple terms:\n\n---\n\n### Part 1: Special Relativity (1905)\n\nThis theory deals with how space and time are related for objects moving at **constant speeds** (not accelerating). It has two main postulates (fundamental assumptions):\n\n1.  **The Principle of Relativity:** The laws of physics are the same for everyone, no matter how fast or in what direction they\'re moving, as long as they\'re moving at a constant speed.\n    *   **Analogy:** If you\'re on a smooth-riding train with the windows closed, you can\'t tell if you\'re moving or standing still just by doing experiments inside the train (like dropping a ball). The physics works the same.\n\n2.  **The Constancy of the Speed of Light:** The speed of light in a vacuum is the same for everyone, regardless of how fast they themselves are moving. It\'s an absolute cosmic speed limit.\n    *   **Analogy:** If you throw a ball forward from a moving car, the ball\'s speed *adds* to the car\'s speed. But if you shine a flashlight forward from a moving spaceship, the light *doesn\'t* go faster than if you shone it from a stationary flashlight. It always travels at the exact same speed (about 300,000 kilometers per second or 186,000 miles per second).\n\n**What are the mind-bending consequences of Special Relativity?**\n\nBecause the speed of light *must* be constant for all observers, other things we thought were constant (like time and distance) have to change!\n\n*   **Time Dilation:** Moving clocks run slower.\n    *   If you fly past Earth in a very fast spaceship, people on Earth would see your clock ticking slower than theirs. And from your perspective, *their* clocks would seem to tick slower! The effect is only noticeable at speeds close to light speed. This means a twin who travels to a distant star at near light speed would return to find their Earth-bound twin had aged more.\n*   **Length Contraction:** Moving objects get shorter in the direction of their motion.\n    *   A spaceship flying past you at near light speed would appear squashed or shorter to you, along the direction it\'s traveling.\n*   **Mass-Energy Equivalence (E=mc²):** Mass and energy are interchangeable.\n    *   This is arguably the most famous equation. It says that mass (M) is a very concentrated form of energy (E), and vice versa. \'c\' is the speed of light, and \'c²\' is a huge number, meaning even a tiny bit of mass can be converted into an enormous amount of energy (like in nuclear reactions or the sun).\n\n---\n\n### Part 2: General Relativity (1915)\n\nThis theory expands on Special Relativity to include **gravity** and **acceleration**. Einstein realized that his previous theory couldn\'t fully explain gravity.\n\n**The Core Idea:** Gravity is not a force that pulls objects together (like Isaac Newton thought). Instead, gravity is the **curvature of spacetime** caused by massive objects.\n\n*   **Analogy:** Imagine a stretched rubber sheet. If you place a bowling ball in the middle, it creates a dip or a "dent" in the sheet. Now, if you roll smaller marbles across the sheet, they don\'t roll in a straight line; they curve inwards towards the bowling ball because of the dip.\n*   **Applying it:**\n    *   Massive objects like Earth or the Sun are like the bowling ball. They warp the "fabric" of spacetime around them.\n    *   Objects like you, me, or planets are like the marbles. We\'re not being "pulled" by a force; we\'re simply following the curves and "dents" that massive objects have created in spacetime. The Earth orbits the Sun because it\'s following the curve in spacetime caused by the Sun\'s immense mass.\n\n**What are the mind-bending consequences of General Relativity?**\n\n*   * ...

# %%
response.content_blocks
# Out:
# [{'type': 'text',
#   'text': 'Albert Einstein\'s theory of relativity is one of the most famous and profound scientific theories, revolutionizing our understanding of space, time, gravity, and the universe. It\'s actually two interconnected theories: **Special Relativity** and **General Relativity**.\n\nLet\'s break them down in simple terms:\n\n---\n\n### Part 1: Special Relativity (1905)\n\nThis theory deals with how space and time are related for objects moving at **constant speeds** (not accelerating). It has two main postulates (fundamental assumptions):\n\n1.  **The Principle of Relativity:** The laws of physics are the same for everyone, no matter how fast or in what direction they\'re moving, as long as they\'re moving at a constant speed.\n    *   **Analogy:** If you\'re on a smooth-riding train with the windows closed, you can\'t tell if you\'re moving or standing still just by doing experiments inside the train (like dropping a ball). The physics works the same.\n\n2.  **The Constancy of the Speed of Light:** The speed of light in a vacuum is the same for everyone, regardless of how fast they themselves are moving. It\'s an absolute cosmic speed limit.\n    *   **Analogy:** If you throw a ball forward from a moving car, the ball\'s speed *adds* to the car\'s speed. But if you shine a flashlight forward from a moving spaceship, the light *doesn\'t* go faster than if you shone it from a stationary flashlight. It always travels at the exact same speed (about 300,000 kilometers per second or 186,000 miles per second).\n\n**What are the mind-bending consequences of Special Relativity?**\n\nBecause the speed of light *must* be constant for all observers, other things we thought were constant (like time and distance) have to change!\n\n*   **Time Dilation:** Moving clocks run slower.\n    *   If you fly past Earth in a very fast spaceship, people on Earth would see your clock ticking slower than theirs. And from your perspective, *their* clocks would seem to tick slower! The effect is only noticeable at speeds close to light speed. This means a twin who travels to a distant star at near light speed would return to find their Earth-bound twin had aged more.\n*   **Length Contraction:** Moving objects get shorter in the direction of their motion.\n    *   A spaceship flying past you at near light speed would appear squashed or shorter to you, along the direction it\'s traveling.\n*   **Mass-Energy Equivalence (E=mc²):** Mass and energy are interchangeable.\n    *   This is arguably the most famous equation. It says that mass (M) is a very concentrated form of energy (E), and vice versa. \'c\' is the speed of light, and \'c²\' is a huge number, meaning even a tiny bit of mass can be converted into an enormous amount of energy (like in nuclear reactions or the sun).\n\n---\n\n### Part 2: General Relativity (1915)\n\nThis theory expands on Special Relativity to include **gravity** and **acceleration**. Einstein realized that his previous theory couldn\'t fully explain gravity.\n\n**The Core Idea:** Gravity is not a force that pulls objects together (like Isaac Newton thought). Instead, gravity is the **curvature of spacetime** caused by massive objects.\n\n*   **Analogy:** Imagine a stretched rubber sheet. If you place a bowling ball in the middle, it creates a dip or a "dent" in the sheet. Now, if you roll smaller marbles across the sheet, they don\'t roll in a straight line; they curve inwards towards the bowling ball because of the dip.\n*   **Applying it:**\n    *   Massive objects like Earth or the Sun are like the bowling ball. They warp the "fabric" of spacetime around them.\n    *   Objects like you, me, or planets are like the marbles. We\'re not being "pulled" by a force; we\'re simply following the curves and "dents" that massive objects have created in spacetime. The Earth orbits the Sun because it\'s following the curve in spacetime caused by the Sun\'s immense mass.\n\n**What are the mind-bending consequences of General Relativity?* ...

# %%
response.usage_metadata
# Out:
# {'input_tokens': 16,
#  'output_tokens': 2583,
#  'total_tokens': 2599,
#  'input_token_details': {'cache_read': 0},
#  'output_token_details': {'reasoning': 1345}}

# %%
response.response_metadata
# Out:
# {'finish_reason': 'STOP',
#  'model_name': 'gemini-2.5-flash',
#  'safety_ratings': [],
#  'model_provider': 'google_genai'}
