# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
import os

# os.environ

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain.messages import AIMessage, HumanMessage, SystemMessage

# %%
gemini3 = "gemini-3-pro-preview"
gemini2 = "gemini-2.5-flash"

system_msg = SystemMessage(content="You are a helpful assistant.")
user_query = HumanMessage(content="Explain the theory of relativity in simple terms.")

msgs = [system_msg, user_query]

# %%
model = ChatGoogleGenerativeAI(model=gemini3)
response = model.invoke(msgs)

# %%
response.text
# Out:
# 'Here is an explanation of Albert Einstein’s Theory of Relativity using simple concepts and analogies.\n\nTo understand it, you have to break it into two parts: **Special Relativity** (about speed) and **General Relativity** (about gravity).\n\n### The Core Idea: It’s all about perspective\n"Relativity" simply means that different events look different depending on how you are moving.\n\nImagine you are on a train moving at 50 mph. You throw a ball forward at 10 mph.\n*   **To you**, the ball is moving at **10 mph**.\n*   **To someone standing on the ground** watching the train go by, the ball is moving at **60 mph** (50 mph train + 10 mph throw).\n\nThe speed of the ball is "relative" to who is looking at it. Einstein took this idea and applied it to the whole universe.\n\n---\n\n### Part 1: Special Relativity (The Speed of Light)\nEinstein realized one weird thing: **Light is different.**\n\nIf you turn on a flashlight on that moving train, the light beam doesn\'t get faster. No matter how fast you are moving, the speed of light is always exactly the same. It is the cosmic speed limit.\n\nBut, if the speed of light *never* changes, something else has to. Einstein discovered that **time and space change.**\n\n**The Big Takeaway:** The faster you move through space, the slower you move through time.\n*   **Example:** Imagine two astronauts who are twins. One stays on Earth; the other flies in a spaceship near the speed of light. When the traveling twin returns, they will be **younger** than the twin who stayed on Earth. Their clock actually ticked slower because they were moving so fast.\n\n---\n\n### Part 2: General Relativity (Gravity)\nTen years later, Einstein figured out how gravity fits into this.\n\nBefore Einstein, Isaac Newton said gravity was a force—like an invisible rope pulling two things together. Einstein said, "No, it\'s not a rope. It\'s a curve."\n\n**The Trampoline Analogy:**\nImagine a large, flat trampoline.\n1.  If you roll a marble across it, it travels in a straight line.\n2.  Now, place a heavy bowling ball in the middle. The fabric curves and dips down.\n3.  If you roll the marble now, it doesn\'t go straight. It curves around the bowling ball. It looks like the bowling ball is pulling the marble, but really, the marble is just following the curve of the fabric.\n\n**The Big Takeaway:**\nSpace and time are like that fabric (physicists call it "spacetime"). Massive objects like the Sun or Earth are heavy enough to bend the fabric of space. Gravity isn\'t a pulling force; it’s just us sliding along the curves created by heavy objects.\n\n### Summary\n1.  **Special Relativity:** Time slows down when you move really fast.\n2.  **General Relativity:** Heavy objects (like planets) bend space, which creates gravity.\n\n**Does this actually affect us?**\nYes! GPS satellites circle the Earth very fast and feel less gravity than we do. Their clocks actually tick at a different speed than clocks on our phones. Engineers have to program the satellites to adjust for Einstein’s theory; otherwise, your Google Maps location would be off by miles every single day!'
