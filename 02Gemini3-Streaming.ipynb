# %% [markdown]
# ## Streaming

# %%
from dotenv import load_dotenv
import os

load_dotenv()
# Out:
# True

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

# %%
gemini2 = "gemini-2.5-flash"
model = ChatGoogleGenerativeAI(model=gemini2)

# %%
query = "Explain the theory of relativity in the simple terms."

for chunk in model.stream(query):
    print(chunk.text, end="", flush=True)
# Out:
# Okay, let's break down Einstein's Theory of Relativity into its two main parts, Special Relativity and General Relativity, using simple language and analogies.
#
# ### The Big Idea: Space and Time are Not Absolute
#
# Before Einstein, people (and Newton) thought space was like a fixed, unchanging stage where events happened, and time was a universal clock ticking away for everyone at the same rate. Einstein said, "Nope! Space and time are flexible, interconnected, and relative to who is observing them."
#
# ---
#
# ### Part 1: Special Relativity (1905)
#
# This part deals with things moving at **constant speeds in a straight line** (no acceleration or gravity). It's based on two mind-bending ideas:
#
# **1. The Laws of Physics Are the Same for Everyone in Steady Motion.**
# *   **Imagine:** You're on a smooth-riding train with no windows. If you toss a ball straight up, it comes straight down. If the train speeds up, slows down, or turns, it would be different. But at a constant speed, everything inside works just as if you were standing still on the ground.
# *   **Meaning:** There's no "absolute" state of rest. Motion is always relative to something else.
#
# **2. The Speed of Light is Constant for Everyone, No Matter What.**
# *   **Imagine:** You're standing still, and a car drives past you at 50 mph. You measure its speed as 50 mph. Now, imagine you're driving in a car at 30 mph in the *same direction* as that first car. You'd measure the first car's speed as 20 mph (50 - 30).
# *   **Now for light:** This rule *doesn't apply* to light! If a flashlight beam passes you, you'll always measure its speed as roughly 186,000 miles per second (or 300,000 km/s). It doesn't matter if you're standing still, running towards it, or running away from it. Light always travels at the same speed for *everyone*. This is the weird part that breaks common sense!
#
# **What Happens Because of These Two Ideas? (The Crazy Consequences!):**
#
# *   **Time Dilation (Time Slows Down):** If you're moving very fast relative to someone else, your clock will tick slower than theirs. Not just a mechanical clock, but your *biological clock* too. You'd age slower!
#     *   **Analogy:** Imagine twins. One stays on Earth, the other travels close to the speed of light in a spaceship for a few years. When the space twin returns, they will be younger than their Earth-bound twin. (This has been proven with atomic clocks!).
#
# *   **Length Contraction (Things Get Shorter):** Objects moving very fast appear shorter in the direction of their motion, as observed by someone standing still.
#     *   **Analogy:** If you could zoom past Earth in a spaceship at near light-speed, you'd see Earth squashed in the direction you were flying, like a pancake.
#
# *   **E=mc² (Energy and Mass are Two Sides of the Same Coin):** This is the most famous equation!
#     *   **E** is Energy, **m** is Mass, **c** is the Speed of Light.
#     *   **Meaning:** A tiny amount of mass can be converted into an enormous amount of energy (because 'c' is such a huge number, and it's squared!). This is how the sun produces energy and how nuclear bombs work. It also means that as an object gets faster and faster, its mass effectively increases, requiring more and more energy to speed it up further. Nothing with mass can ever reach the speed of light because it would require infinite energy.
#
# ---
#
# ### Part 2: General Relativity (1915)
#
# This part expands on Special Relativity by including **gravity and acceleration**.
#
# **The Big Idea: Gravity Isn't a Force, It's the Curvature of Spacetime.**
#
# *   **Before Einstein:** Newton said gravity was a mysterious force pulling objects together.
# *   **Einstein's Genius:** He said gravity isn't a force *pulling* things; it's the result of massive objects (like planets and stars) **bending and warping the fabric of spacetime itself.**
# *   **What is "Spacetime"?** Think of it as a four-dimensional blanket that combines the three dimensions of space (up/down, left/right, forward/backward) with the one dimension of time (past/future) into a single, interconnected fabric.
#
# *   **Analogy: The Trampoline.**
#     *   Imagine a stretched-out rubber sheet (that's spacetime).
#     *   Now, place a bowling ball in the middle (that's a massive object like the Sun). The bowling ball creates a dip or curve in the rubber sheet.
#     *   Now, roll a marble nearby (that's a planet like Earth). The marble doesn't get "pulled" towards the bowling ball; it simply follows the curve in the sheet created by the bowling ball.
#     *   **This is gravity!** The Earth isn't pulled by the Sun; it's following the curves and dips the Sun has created in the spacetime fabric.
#
# **What Happens Because of This Idea? (Amazing Predictions!):**
#
# *   **Bending of Light:** Because spacetime is curved, even light (which has no mass) will follow those curves. So, light from distant stars appears to bend around massive objects like the Sun. This was one of the first proofs of General Relativity during a solar eclipse in 1919.
#
# *   **Black Holes:** If an object is incredibly massive and dense, it can warp spacetime so much that it creates a "hole" from which nothing, not even light, can escape.
#
# *   **Gravitational Lensing:** Massive galaxies can act like giant cosmic magnifying glasses, bending the light from even more distant galaxies behind them, allowing us to see them.
#
# *   **Gravitational Waves:** When extremely massive objects (like black holes) accelerate and collide, they create "ripples" in the fabric of spacetime that travel outward like waves in a pond. These were predicted by Einstein and finally detected in 2015.
#
# ---
#
# ### In Simple Summary:
#
# *   **Special Relativity:** When you move really fast (but steadily), space shrinks, and time slows down for you compared to someone standing still. Mass and energy are interchangeable. The speed of light is the universal speed limit and always measured the same by everyone.
# *   **General Relativity:** Gravity isn't a mysterious force; it's just big stuff (mass/energy) bending the very fabric of space and time around it. Other stuff then just rolls along those curves.
#
# Einstein's theories revolutionized our understanding of the universe, from the smallest particles to the largest galaxies, and continue to be essential for technologies like GPS. It's truly incredible how these fundamental ideas, born from thought experiments, accurately describe reality.
